# %% [markdown]
# # Likes Report
# - Morgan Rawski
# - 9/7/2025

# %% [markdown]
# ## Section 1: Questions about data
# 1. Who or what is the source of your personal Instagram data? (You downloaded the data, but did you create it?)
# - This is my Instagram data that was downloaded from Meta. Meta put it together based on my interactions with their Instagram and Facebook apps.
# 2. Why was this data created and what purposes can the data serve?
# - This data was created to allow users to see their statistics in my social media activity and for those interested, they can make a hypothesis to evaluate based on this data to find trends or significance to their social media interactions.
# 3. In what ways may this data be reliable?
# - This data may be reliable because it is raw data that has not been tweaked in any way and it is my data, so it is more relavent than if I were using someone else's data.
# 4. In what ways may this data be unreliable?
# - It may not tell me about something that I am looking for specifically in my data and I often do not have my precise location turned on which can affect certain details for the evaluation of the data.

# %% [markdown]
# ## Section 2
# open and load the json file

# %%
# These are the imports we need
import json
import pandas as pd
import matplotlib as plt

# %%
path = r"/Users/morawski28/Downloads/instagram-mormraw28-2025-09-10-TEvec6p4/your_instagram_activity/likes/liked_posts.json"
with open(path) as l:
    dict = json.load(l)

# %% [markdown]
# ## Section 3
# Convert the data into DataFrame object and assign it to a new variable using pandas DataFrame function.

# %%
df = pd.DataFrame(dict)
df.head()
# Out:
#                                    likes_media_likes
# 0  {'title': 'barstoolkent', 'string_list_data': ...
# 1  {'title': 'valorynewton', 'string_list_data': ...
# 2  {'title': 'sierratwirls88', 'string_list_data'...
# 3  {'title': 'ellie_fish14', 'string_list_data': ...
# 4  {'title': 'fab_ksu', 'string_list_data': [{'hr...

# %%
dict.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
df_tidy = pd.DataFrame(dict['likes_media_likes'])
df_tidy.head()
# Out:
#             title                                   string_list_data
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...

# %% [markdown]
# ## Section 4
# Extract and input like's timestamp into table

# %%
df_tidy['string_list_data'].iloc[0]
# Out:
# [{'href': 'https://www.instagram.com/p/DOWU5HLETt1/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1757358467}]

# %%
type(df_tidy['string_list_data'].iloc[0])
# Out:
# list

# %%
len(df_tidy['string_list_data'].iloc[0])
# Out:
# 1

# %%
df_tidy['string_list_data'].iloc[0][0]
# Out:
# {'href': 'https://www.instagram.com/p/DOWU5HLETt1/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1757358467}

# %%
df_tidy['string_list_data'].iloc[0][0]['timestamp']
# Out:
# 1757358467

# %%
df_tidy['Time of Like'] = [ i[0]['timestamp'] for i in df_tidy['string_list_data']]

df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like
# 0    1757358467
# 1    1757358317
# 2    1757358302
# 3    1757358290
# 4    1757358287

# %%
# good to have
from datetime import datetime
df_tidy['Date of Like'] = [ datetime.fromtimestamp(i[0]['timestamp']) for i in df_tidy['string_list_data']]

# %%
df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like        Date of Like
# 0    1757358467 2025-09-08 15:07:47
# 1    1757358317 2025-09-08 15:05:17
# 2    1757358302 2025-09-08 15:05:02
# 3    1757358290 2025-09-08 15:04:50
# 4    1757358287 2025-09-08 15:04:47

# %%
df_tidy['href'] = [ i[0]['href'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like        Date of Like                                      href
# 0    1757358467 2025-09-08 15:07:47  https://www.instagram.com/p/DOWU5HLETt1/
# 1    1757358317 2025-09-08 15:05:17  https://www.instagram.com/p/DOTn2K3Do5e/
# 2    1757358302 2025-09-08 15:05:02  https://www.instagram.com/p/DOTsYfskcnj/
# 3    1757358290 2025-09-08 15:04:50  https://www.instagram.com/p/DOT1lviAC3s/
# 4    1757358287 2025-09-08 15:04:47  https://www.instagram.com/p/DOWM7AOjuHj/

# %%
df_tidy['value'] = [ i[0]['value'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like        Date of Like                                      href  \
# 0    1757358467 2025-09-08 15:07:47  https://www.instagram.com/p/DOWU5HLETt1/
# 1    1757358317 2025-09-08 15:05:17  https://www.instagram.com/p/DOTn2K3Do5e/
# 2    1757358302 2025-09-08 15:05:02  https://www.instagram.com/p/DOTsYfskcnj/
# 3    1757358290 2025-09-08 15:04:50  https://www.instagram.com/p/DOT1lviAC3s/
# 4    1757358287 2025-09-08 15:04:47  https://www.instagram.com/p/DOWM7AOjuHj/
#
#   value
# 0  ð
# 1  ð
# 2  ð
# 3  ð
# 4  ð

# %%
df_tidy.drop(columns = ['string_list_data'])
# Out:
#                 title  Time of Like        Date of Like  \
# 0        barstoolkent    1757358467 2025-09-08 15:07:47
# 1        valorynewton    1757358317 2025-09-08 15:05:17
# 2      sierratwirls88    1757358302 2025-09-08 15:05:02
# 3        ellie_fish14    1757358290 2025-09-08 15:04:50
# 4             fab_ksu    1757358287 2025-09-08 15:04:47
# ...               ...           ...                 ...
# 3110  crystal_demilio    1725926714 2024-09-09 20:05:14
# 3111       shotbyjoah    1725926443 2024-09-09 20:00:43
# 3112  sienna.garcia02    1725831094 2024-09-08 17:31:34
# 3113      addisongs22    1725831046 2024-09-08 17:30:46
# 3114     ellie.rymers    1725830592 2024-09-08 17:23:12
#
#                                           href value
# 0     https://www.instagram.com/p/DOWU5HLETt1/  ð
# 1     https://www.instagram.com/p/DOTn2K3Do5e/  ð
# 2     https://www.instagram.com/p/DOTsYfskcnj/  ð
# 3     https://www.instagram.com/p/DOT1lviAC3s/  ð
# ...

# %%
type(df_tidy['string_list_data'].iloc[0])
# Out:
# list

# %%
len(df_tidy['string_list_data'].iloc[0])
# Out:
# 1

# %%
df_tidy['string_list_data'].iloc[0][0]
# Out:
# {'href': 'https://www.instagram.com/p/DOWU5HLETt1/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1757358467}

# %%
df_tidy['string_list_data'].iloc[0][0]['timestamp']
# Out:
# 1757358467

# %%
df_tidy['Time of Like'] = [ i[0]['timestamp'] for i in df_tidy['string_list_data']]

df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like        Date of Like                                      href  \
# 0    1757358467 2025-09-08 15:07:47  https://www.instagram.com/p/DOWU5HLETt1/
# 1    1757358317 2025-09-08 15:05:17  https://www.instagram.com/p/DOTn2K3Do5e/
# 2    1757358302 2025-09-08 15:05:02  https://www.instagram.com/p/DOTsYfskcnj/
# 3    1757358290 2025-09-08 15:04:50  https://www.instagram.com/p/DOT1lviAC3s/
# 4    1757358287 2025-09-08 15:04:47  https://www.instagram.com/p/DOWM7AOjuHj/
#
#   value
# 0  ð
# 1  ð
# 2  ð
# 3  ð
# 4  ð

# %%
# good to have
from datetime import datetime
df_tidy['Date of Like'] = [ datetime.fromtimestamp(i[0]['timestamp']) for i in df_tidy['string_list_data']]

# %%
df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like        Date of Like                                      href  \
# 0    1757358467 2025-09-08 15:07:47  https://www.instagram.com/p/DOWU5HLETt1/
# 1    1757358317 2025-09-08 15:05:17  https://www.instagram.com/p/DOTn2K3Do5e/
# 2    1757358302 2025-09-08 15:05:02  https://www.instagram.com/p/DOTsYfskcnj/
# 3    1757358290 2025-09-08 15:04:50  https://www.instagram.com/p/DOT1lviAC3s/
# 4    1757358287 2025-09-08 15:04:47  https://www.instagram.com/p/DOWM7AOjuHj/
#
#   value
# 0  ð
# 1  ð
# 2  ð
# 3  ð
# 4  ð

# %%
df_tidy['href'] = [ i[0]['href'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like        Date of Like                                      href  \
# 0    1757358467 2025-09-08 15:07:47  https://www.instagram.com/p/DOWU5HLETt1/
# 1    1757358317 2025-09-08 15:05:17  https://www.instagram.com/p/DOTn2K3Do5e/
# 2    1757358302 2025-09-08 15:05:02  https://www.instagram.com/p/DOTsYfskcnj/
# 3    1757358290 2025-09-08 15:04:50  https://www.instagram.com/p/DOT1lviAC3s/
# 4    1757358287 2025-09-08 15:04:47  https://www.instagram.com/p/DOWM7AOjuHj/
#
#   value
# 0  ð
# 1  ð
# 2  ð
# 3  ð
# 4  ð

# %%
df_tidy['value'] = [ i[0]['value'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#             title                                   string_list_data  \
# 0    barstoolkent  [{'href': 'https://www.instagram.com/p/DOWU5HL...
# 1    valorynewton  [{'href': 'https://www.instagram.com/p/DOTn2K3...
# 2  sierratwirls88  [{'href': 'https://www.instagram.com/p/DOTsYfs...
# 3    ellie_fish14  [{'href': 'https://www.instagram.com/p/DOT1lvi...
# 4         fab_ksu  [{'href': 'https://www.instagram.com/p/DOWM7AO...
#
#    Time of Like        Date of Like                                      href  \
# 0    1757358467 2025-09-08 15:07:47  https://www.instagram.com/p/DOWU5HLETt1/
# 1    1757358317 2025-09-08 15:05:17  https://www.instagram.com/p/DOTn2K3Do5e/
# 2    1757358302 2025-09-08 15:05:02  https://www.instagram.com/p/DOTsYfskcnj/
# 3    1757358290 2025-09-08 15:04:50  https://www.instagram.com/p/DOT1lviAC3s/
# 4    1757358287 2025-09-08 15:04:47  https://www.instagram.com/p/DOWM7AOjuHj/
#
#   value
# 0  ð
# 1  ð
# 2  ð
# 3  ð
# 4  ð

# %%
df_tidy.drop(columns = ['string_list_data'])
# Out:
#                 title  Time of Like        Date of Like  \
# 0        barstoolkent    1757358467 2025-09-08 15:07:47
# 1        valorynewton    1757358317 2025-09-08 15:05:17
# 2      sierratwirls88    1757358302 2025-09-08 15:05:02
# 3        ellie_fish14    1757358290 2025-09-08 15:04:50
# 4             fab_ksu    1757358287 2025-09-08 15:04:47
# ...               ...           ...                 ...
# 3110  crystal_demilio    1725926714 2024-09-09 20:05:14
# 3111       shotbyjoah    1725926443 2024-09-09 20:00:43
# 3112  sienna.garcia02    1725831094 2024-09-08 17:31:34
# 3113      addisongs22    1725831046 2024-09-08 17:30:46
# 3114     ellie.rymers    1725830592 2024-09-08 17:23:12
#
#                                           href value
# 0     https://www.instagram.com/p/DOWU5HLETt1/  ð
# 1     https://www.instagram.com/p/DOTn2K3Do5e/  ð
# 2     https://www.instagram.com/p/DOTsYfskcnj/  ð
# 3     https://www.instagram.com/p/DOT1lviAC3s/  ð
# ...

# %% [markdown]
# ## Section 5

# %%
df_tidy.groupby('title').count().sort_values('value', ascending = False)
# Out:
#                     string_list_data  Time of Like  Date of Like  href  value
# title
# nickhuenefeld                    134           134           134   134    134
# signaturebankna                  113           113           113   113    113
# devs_springfieldsb               113           113           113   113    113
# trisigmaksu                      110           110           110   110    110
# fab_ksu                          107           107           107   107    107
# ...                              ...           ...           ...   ...    ...
# joahherman                         1             1             1     1      1
# john__stanson                      1             1             1     1      1
# jon_huston3                        1             1             1     1      1
# jonathan.specht8                   1             1             1     1      1
# yuletide.family                    1             1             1     1      1
#
# [416 rows x 5 columns]

# %% [markdown]
# # Section 6
# - In a Markdown cell, state a hypothesis that could be tested using some of your personal Instagram, Facebook, or TikTok data (other than the "likes" data file).
#     - I would like to test how often I view with people's stories on Instagram. I believe that I view with Instagram stories more in the evening because I have more time to look at them.
# - Explain the theoretical and statistical elements of your hypothesis.
#     - The theoretical element of my hypothesis is that I think I can use my Instagram story data to see if there is a trend of when I view all the different stories that appear on my Instagram profile. The statistical element of my hypothesis is that I want to try to pull my timestamp data from Instagram and sort it to see if I view them more in the morning or in the evening.

# %% [markdown]
# # Section 7
# - After reviewing the other files in your personal social media data, choose a JSON file that you think might help you test your hypothesis.
# - Explain what you think the JSON file contains and how it will help you test your hypothesis.
#     - I think that the stories JSON file may help me to test my hypothesis because it is all the data surrounding stories associated with my Instagram profile, but I am nervous that it may not give me the specific information that I am looking for.

# %% [markdown]
# # Section 8
# open and load the JSON data

# %%
# These are the imports we need
import json
import pandas as pd
import matplotlib as plt

# %%
path = r"/Users/morawski28/Downloads/instagram-mormraw28-2025-09-10-TEvec6p4/your_instagram_activity/media/stories.json"
with open(path) as l:
    dict = json.load(l)

# %% [markdown]
# # Section 9
# Convert the data to the most "tidy" DataFrame object you can.

# %%
df = pd.DataFrame(dict)
df.head()
# Out:
#                                           ig_stories
# 0  {'uri': 'media/stories/202509/540566439_179147...
# 1  {'uri': 'media/stories/202509/541196959_179147...
# 2  {'uri': 'media/stories/202509/542744242_179147...
# 3  {'uri': 'media/stories/202509/541949739_179147...
# 4  {'uri': 'media/stories/202509/541141665_179146...

# %%
dict.keys()
# Out:
# dict_keys(['ig_stories'])

# %%
df_tidy = pd.DataFrame(dict['ig_stories'])
df_tidy.head()
# Out:
#                                                  uri  creation_timestamp  \
# 0  media/stories/202509/540566439_179147986951895...          1757031529
# 1  media/stories/202509/541196959_179147872441895...          1757018227
# 2  media/stories/202509/542744242_179147712271895...          1757005667
# 3  media/stories/202509/541949739_179147333071895...          1757002441
# 4  media/stories/202509/541141665_179146118731895...          1756908305
#
#                                       media_metadata  \
# 0  {'photo_metadata': {'exif_data': [{'device_id'...
# 1  {'photo_metadata': {'exif_data': [{'device_id'...
# 2  {'photo_metadata': {'exif_data': [{'device_id'...
# 3  {'photo_metadata': {'exif_data': [{'device_id'...
# 4  {'photo_metadata': {'exif_data': [{'device_id'...
#
#                                                title     cross_post_source  \
# 0                           @alimcdonald.19 ðð  {'source_app': 'FB'}
# ...

# %%
# good to have
from datetime import datetime
df_tidy['Date of Like'] = [ datetime.fromtimestamp(i) for i in df_tidy['creation_timestamp']]

#df_tidy['Date of Like'] = [ datetime.fromtimestamp(i[0]['timestamp']) for i in df_tidy['string_list_data']]
df_tidy.head(10)
# Out:
#                                                  uri  creation_timestamp  \
# 0  media/stories/202509/540566439_179147986951895...          1757031529
# 1  media/stories/202509/541196959_179147872441895...          1757018227
# 2  media/stories/202509/542744242_179147712271895...          1757005667
# 3  media/stories/202509/541949739_179147333071895...          1757002441
# 4  media/stories/202509/541141665_179146118731895...          1756908305
# 5  media/stories/202509/541546732_179145557401895...          1756868136
# 6  media/stories/202508/539455069_179135361481895...          1756094084
# 7  media/stories/202508/538182030_179134739761895...          1756046618
# 8  media/stories/202508/533769874_179130070261895...          1755708046
# 9  media/stories/202508/AQMyfZR1Cu1msXDueQcVL8ZVL...          1755354095
#
#                                       media_metadata  \
# 0  {'photo_metadata': {'exif_data': [{'device_id'...
# 1  {'photo_metadata': {'exif_data': [{'device_id'...
# ...

# %%
df_tidy.drop(columns = ['cross_post_source', 'dubbing_info', 'media_variants', 'media_metadata', 'uri'])
# Out:
#     creation_timestamp                                              title  \
# 0           1757031529                           @alimcdonald.19 ðð
# 1           1757018227  @itsss.jocy  @alimcdonald.19  @_abigailkinney ...
# 2           1757005667                               @itsss.jocy ðð©·
# 3           1757002441                          @adelaide.sallas ðð
# 4           1756908305  Come see me at 6 tonight out front of the sigm...
# ..                 ...                                                ...
# 82          1729640061  @itsss.jocy  #ihavethebestbigever  @sophiamart...
# 83          1729518305                             So much fun yesterday!
# 84          1729308042  So glad to be a part of the VIP fam! Canât w...
# 85          1729185502
# 86          1727057929  Thank you Caitlyn for showing me around today ...
#
#           Date of Like
# 0  2025-09-04 20:18:49
# 1  2025-09-04 16:37:07
# 2  2025-09-04 13:07:47
# 3  2025-09-04 12:14:01
# ...

# %%
df_tidy.head(10)
# every time I try to get the first 10 rows to show up after dropping the columns above it reverts back to the original table without dropping the columns and I cannot figure out how to fix it.
# Out:
#                                                  uri  creation_timestamp  \
# 0  media/stories/202509/540566439_179147986951895...          1757031529
# 1  media/stories/202509/541196959_179147872441895...          1757018227
# 2  media/stories/202509/542744242_179147712271895...          1757005667
# 3  media/stories/202509/541949739_179147333071895...          1757002441
# 4  media/stories/202509/541141665_179146118731895...          1756908305
# 5  media/stories/202509/541546732_179145557401895...          1756868136
# 6  media/stories/202508/539455069_179135361481895...          1756094084
# 7  media/stories/202508/538182030_179134739761895...          1756046618
# 8  media/stories/202508/533769874_179130070261895...          1755708046
# 9  media/stories/202508/AQMyfZR1Cu1msXDueQcVL8ZVL...          1755354095
#
#                                       media_metadata  \
# 0  {'photo_metadata': {'exif_data': [{'device_id'...
# 1  {'photo_metadata': {'exif_data': [{'device_id'...
# ...

# %% [markdown]
# # Section 10
# - In a Markdown cell, describe what you think the data in the DataFrame represents, whether the DataFrame meets tidy principles, and whether the data can be used to test your hypothesis.
#     - In the DataFrame that I created above, I believe the data represents both the Instagram reels that I interact with and the ones that I create. I think that my DataFrame almost meets the standard of the tidy principles. In the execution of this assignment, I struggled with getting it to organize to the first 10 rows after I dropped some of the columns, as well as trying to organize the table by a certain value. Unfortunately, I do not think that this data is what I wanted to test my hypothesis. I wanted more to find data that would show my views of Instagram stories and what time of day that I do that most, but I think this data is more about Instagram story interactions, including the stories that I create. I do not know if Instagram provides this kind of data and I was just not looking at the right file, but this did not work out to helping test my hypothesis.
